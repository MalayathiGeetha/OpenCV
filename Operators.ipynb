# %% [markdown]
# <a href="https://colab.research.google.com/github/MalayathiGeetha/OpenCV/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-394b6fa0-c670-49c0-a8f4-5c7e0ce140a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-394b6fa0-c670-49c0-a8f4-5c7e0ce140a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Arithmetic Operations On Images

import cv2
from google.colab.patches import cv2_imshow

img1=cv2.imread("boy1.jpeg")
img2=cv2.imread("abdul kalam.jpeg")

img1=cv2.resize(img1,(500,500))
img2=cv2.resize(img2,(500,500))

# new_img=cv2.addWeighted(img1,1,img2,1,1)

new_img=cv2.subtract(img2,img1)
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
import numpy as np

# new=cv2.bitwise_and(img1,img2)
# new=cv2.bitwise_or(img1,img2)
# new=cv2.bitwise_xor(img1,img2)
new=cv2.bitwise_not(img1)
h=np.hstack((img1,img2,new))

cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>
